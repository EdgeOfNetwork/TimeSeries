# %%
import sys
import time
import os
import glob
from time import sleep
import datetime
import pytz
import argparse

import numpy as np
import pandas as pd
import pickle
import joblib

import scipy # 여기에 오타가 나있었네 어째 불안하다
import sklearn
import xgboost as xgb
from sklearn.metrics import accuracy_score, classification_report

from scipy.stats import skew, kurtosis
#from Current_Feature_Extractor import Extract_Time_Features, Extract_Phase_Features, Extract_Freq_Features

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class Extract_Time_Features:    
    def __init__(self, rawTimeData):
        self._TimeFeatures = []
        self._rawTimeData = rawTimeData

    def AbsMax(self):
        self._absmax = np.abs(self._rawTimeData).max(axis=1)
        return self._absmax
    
    def AbsMean(self):
        self._absmean = np.abs(self._rawTimeData).mean(axis=1)
        return self._absmean
    
    def P2P(self):
        self._peak2peak = np.max(self._rawTimeData,axis=1) - np.min(self._rawTimeData,axis=1)
        return self._peak2peak
    
    def Skewness(self):
        self._skewness = skew(self._rawTimeData, axis=1, nan_policy='raise')
        return self._skewness
    
    def Kurtosis(self):
        self._kurtosis = kurtosis(self._rawTimeData, axis=1, fisher=False)
        return self._kurtosis

    def RMS(self):
        self._rms = np.sqrt(np.sum(self._rawTimeData**2, axis=1) / self._rawTimeData.shape[1])
        return self._rms
    
    def CrestFactor(self):
        self._cresfactor = self.P2P() / self.RMS()
        return self._cresfactor
    
    def ShapeFactor(self):
        self._shapefactor = self.RMS() / self.AbsMean()
        return self._shapefactor
    
    def ImpulseFactor(self):
        self._impulsefactor = self.AbsMax() / self.AbsMean()
        return self._impulsefactor

    def Features(self):
        # Time-domain Features #
        self._TimeFeatures.append(self.AbsMax())        # Feature 1: Absolute Maximum 
        self._TimeFeatures.append(self.AbsMean())       # Feature 2: Absolute Mean
        self._TimeFeatures.append(self.P2P())           # Feature 3: Peak-to-Peak
        self._TimeFeatures.append(self.RMS())           # Feature 4: Root-mean-square
        self._TimeFeatures.append(self.Skewness())      # Feature 5: Skewness
        self._TimeFeatures.append(self.Kurtosis())      # Feature 6: Kurtosis
        self._TimeFeatures.append(self.CrestFactor())   # Feature 7: Crest Factor
        self._TimeFeatures.append(self.ShapeFactor())   # Feature 8: Shape Factor
        self._TimeFeatures.append(self.ImpulseFactor()) # Feature 9: Impulse Factor
                
        return np.asarray(self._TimeFeatures)

# %%
#%%  Define class for phase feature extraction ##
class Extract_Phase_Features:    
    def __init__(self, rawTimeData, Fs):
        self._PhaseFeatures = []
        self._rawTimeData = rawTimeData - np.expand_dims(np.mean(rawTimeData,axis=1),axis=1) # Raw time data
        self._Fs = Fs                    # Sampling frequency [Hz]
        
        # Phase Shift #
    
    def Shift(self):
        
        _r = self._rawTimeData[0]
        _s = self._rawTimeData[1]
        _t = self._rawTimeData[2]
        
        _N = self._rawTimeData.shape[1]
        
        _t = np.linspace(0.0, ((_N - 1) / self._Fs), _N)
        _dts = np.linspace(-_t[-1], _t[-1], (2 * _N) - 1)
        
        # RS Phase shift
        self._RS_corr = np.correlate(_r, _s, 'full')
        self._RS_t = _dts[self._RS_corr.argmax()]
        self._RS_phase = ((2.0 * np.pi) * ((self._RS_t / (1.0 / self._Fs)) % 1.0)) - np.pi
        
        # ST Phase shift
        self._ST_corr = np.correlate(_s, _t, 'full')
        self._ST_t = _dts[self._ST_corr.argmax()]
        self._ST_phase = ((2.0 * np.pi) * ((self._ST_t / (1.0 / self._Fs)) % 1.0)) - np.pi
        
         # TR Phase shift
        self._TR_corr = np.correlate(_t, _r, 'full')
        self._TR_t = _dts[self._TR_corr.argmax()]
        self._TR_phase = ((2.0 * np.pi) * ((self._TR_t / (1.0 / self._Fs)) % 1.0)) - np.pi
        
        # Phase Level shift
        self._RS_level = _r.max() - _s.max()
        self._ST_level = _s.max() - _t.max()
        self._TR_level = _t.max() - _r.max()
        
        return (self._RS_phase, self._ST_phase, self._TR_phase, self._RS_level, self._ST_level, self._TR_level)
    
    
    def Features(self):
        shift = self.Shift()
        
        self._PhaseFeatures.append(shift[0])
        self._PhaseFeatures.append(shift[1])
        self._PhaseFeatures.append(shift[2])
        self._PhaseFeatures.append(shift[3])
        self._PhaseFeatures.append(shift[4])
        self._PhaseFeatures.append(shift[5])
        
        return np.asarray(self._PhaseFeatures)

# %%
#%%  Define class for frequency feature extraction ##
class Extract_Freq_Features:    
    def __init__(self, rawTimeData, rpm, Fs):
        self._FreqFeatures = []
        # Remove bias (subtract mean by each channel) #
        self._rawTimeData = rawTimeData - np.expand_dims(np.mean(rawTimeData,axis=1),axis=1) # Raw time data
        
        self._Fs = Fs                    # Sampling frequency [Hz]
        self._rpm = rpm/60               # RPM for every second [Hz]
       
    def FFT(self):
        # Perform FFT #
        _N = self._rawTimeData.shape[1]
        _dt = 1/self._Fs
        _yf_temp = np.fft.fft(self._rawTimeData)
        self._yf = np.abs(_yf_temp[:,:int(_N/2)]) / (_N/2)
        self._xf = np.fft.fftfreq(_N, d=_dt)[:int(_N/2)]
        
        return self._xf, self._yf
    
    def Freq_IDX(self):
        _xf,_yf = self.FFT()
        
        # Motor #
        # find frequency index of 1x #
        self._Freq_1x = self._rpm
        self._1x_idx_Temp = abs(_xf - self._Freq_1x).argmin()
        self._1x_idx_Temp = self._1x_idx_Temp - 2 + np.argmax(self._yf[0][np.arange(self._1x_idx_Temp-2, self._1x_idx_Temp+3)])
        self._1x_idx = np.arange(self._1x_idx_Temp-1, self._1x_idx_Temp+2)

        # find frequency index of 2x #
        self._Freq_2x = self._xf[self._1x_idx[1]] * 2
        self._2x_idx_Temp = abs(_xf - self._Freq_2x).argmin()
        self._2x_idx_Temp = self._2x_idx_Temp - 5 + np.argmax(self._yf[0][np.arange(self._2x_idx_Temp-5, self._2x_idx_Temp+6)])
        self._2x_idx = np.arange(self._2x_idx_Temp-1, self._2x_idx_Temp+2)
        
        # find frequency index of 3x #
        self._Freq_3x = self._xf[self._1x_idx[1]] * 3
        self._3x_idx_Temp = abs(_xf - self._Freq_3x).argmin()
        self._3x_idx_Temp = self._3x_idx_Temp - 5 + np.argmax(self._yf[0][np.arange(self._3x_idx_Temp-5, self._3x_idx_Temp+6)])
        self._3x_idx = np.arange(self._3x_idx_Temp-1, self._3x_idx_Temp+2)
        
        # find frequency index of 4x #
        self._Freq_4x = self._xf[self._1x_idx[1]]  * 4
        self._4x_idx_Temp = abs(_xf - self._Freq_4x).argmin()
        self._4x_idx_Temp = self._4x_idx_Temp - 5 + np.argmax(self._yf[0][np.arange(self._4x_idx_Temp-5, self._4x_idx_Temp+6)])
        self._4x_idx = np.arange(self._4x_idx_Temp-1, self._4x_idx_Temp+2)
        
        
        return (self._1x_idx, self._2x_idx, self._3x_idx, self._4x_idx)

    def Features(self):
        _xf, _yf = self.FFT()
        idx = self.Freq_IDX()
                
        # Freq-domain Features #
        self._1x_Feature = np.sum(_yf[:, idx[0]], axis=1) 
        self._2x_Feature = np.sum(_yf[:, idx[1]], axis=1) 
        self._3x_Feature = np.sum(_yf[:, idx[2]], axis=1) 
        self._4x_Feature = np.sum(_yf[:, idx[3]], axis=1)
                
        self._FreqFeatures.append(self._1x_Feature)
        self._FreqFeatures.append(self._2x_Feature)
        self._FreqFeatures.append(self._3x_Feature)
        self._FreqFeatures.append(self._4x_Feature)
        
        return np.asarray(self._FreqFeatures)

# %%
def validation(filename):
        
    try:
        cur = pd.read_csv(filename, header=None, skiprows=9)
        cur = np.asarray(cur)[:,1:4].transpose()

        meta = pd.read_csv(filename, header=None, skiprows=4, nrows=1)
        rpm = int(meta[2])

        fs = pd.read_csv(filename, header=None, skiprows=6, nrows=1)
        Fs = int(fs[1])

        TimeFeatureExtractor = Extract_Time_Features(cur)
        features_time = TimeFeatureExtractor.Features().flatten()

        PhaseFeatureExtractor = Extract_Phase_Features(cur, Fs)
        features_phase = PhaseFeatureExtractor.Features().flatten()
        FreqFeatureExtractor = Extract_Freq_Features(cur, rpm, Fs)
        features_freq = FreqFeatureExtractor.Features().flatten()

        features = np.concatenate((features_time, features_phase, features_freq))
        data = pd.DataFrame(features).T

        data.columns = [
               'R_AbsMax', 'S_AbsMax', 'T_AbsMax', 'R_AbsMean', 'S_AbsMean','T_AbsMean',
               'R_P2P', 'S_P2P', 'T_P2P', 'R_RMS', 'S_RMS', 'T_RMS', 
               'R_Skewness', 'S_Skewness', 'T_Skewness', 'R_Kurtosis', 'S_Kurtosis', 'T_Kurtosis',
               'R_Crest', 'S_Crest', 'T_Crest', 'R_Shape', 'S_Shape', 'T_Shape',
               'R_Impulse', 'S_Impulse', 'T_Impulse',
               'RS_phase', 'ST_phase', 'TR_phase', 'RS_Level', 'ST_Level', 'TR_Level',
               'R_1x', 'S_1x', 'T_1x', 'R_2x', 'S_2x', 'T_2x',
               'R_3x', 'S_3x', 'T_3x', 'R_4x', 'S_4x', 'T_4x'
               ]

        data['WATT'] = meta[3]
        y = pd.read_csv(filename, header=None, skiprows=3, nrows=1)
        y = y[1]

    except (NameError, IndexError, TypeError, pd.errors.EmptyDataError):
        print('Source Data Error')
        
    else:
        df = data[['WATT', 'R_AbsMax', 'S_AbsMax', 'T_AbsMax', 'R_AbsMean', 'S_AbsMean','T_AbsMean',
                   'R_P2P', 'S_P2P', 'T_P2P', 'R_RMS', 'S_RMS', 'T_RMS', 
                   'R_Skewness', 'S_Skewness', 'T_Skewness', 'R_Kurtosis', 'S_Kurtosis', 'T_Kurtosis',
                   'R_Crest', 'S_Crest', 'T_Crest', 'R_Shape', 'S_Shape', 'T_Shape',
                   'R_Impulse', 'S_Impulse', 'T_Impulse',
                   'RS_phase', 'ST_phase', 'TR_phase', 'RS_Level', 'ST_Level', 'TR_Level',
                   'R_1x', 'S_1x', 'T_1x', 'R_2x', 'S_2x', 'T_2x',
                   'R_3x', 'S_3x', 'T_3x', 'R_4x', 'S_4x', 'T_4x']]

        #norm = np.load('current_norm.npy')#norm
        #X = (df - norm[0]) / norm[1]

        xgb_joblib = joblib.load('/content/drive/MyDrive/SFEP/dataset/current/current_xgb.pkl') 
        y_pred = xgb_joblib.predict(df)
        name = os.path.basename(filename)
        print("Filename:%s, Prediction:%s, Y_Target:%d" % (name, y_pred[0], y))
        
    return y_pred[0], y[0]

# %%
def framework():
    print('########## 전류 유효 검증 시작 #############')
    print('시작시간(UCT+09:00)',datetime.datetime.now(pytz.timezone('Asia/Seoul')).strftime("%Y-%m-%d %H:%M:%S"))
    print('_Python.version:', sys.version)
    print('_Scipy.version:',scipy.__version__)
    print('_XGBoost.version:',xgb.__version__)
    print('_Sklearn.version:',sklearn.__version__)

# %%
framework()
# Out:
# ########## 전류 유효 검증 시작 #############
# 시작시간(UCT+09:00) 2021-08-09 19:58:03
# _Python.version: 3.7.11 (default, Jul  3 2021, 18:01:19)
# [GCC 7.5.0]
# _Scipy.version: 1.4.1
# _XGBoost.version: 1.4.2
# _Sklearn.version: 0.22.2.post1

# %%
# !pip install xgboost==1.4.2
# Out:
# Collecting xgboost==1.4.2
#   Downloading xgboost-1.4.2-py3-none-manylinux2010_x86_64.whl (166.7 MB)
#      |████████████████████████████████| 166.7 MB 8.4 kB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost==1.4.2) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost==1.4.2) (1.19.5)
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
# Successfully installed xgboost-1.4.2

# %%
import xgboost
print(xgboost.compat.__file__)
print(xgboost.compat.XGBoostLabelEncoder)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/compat.py
# <class 'xgboost.compat.XGBoostLabelEncoder'>

# %%
datapath = glob.glob("/content/drive/MyDrive/SFEP/dataset/current" + '**/**/*.csv', recursive=True)

# %%
type(datapath)
# Out:
# list

# %%
start = time.time()

#normal = 

# parser = argparse.ArgumentParser()
# parser.add_argument('--path', default='current', type=str)
# args = parser.parse_args()


#datapath = glob.glob("/content/drive/MyDrive/SFEP/dataset/current", recursive=True)

#datapath = glob.glob(args.path + '**/**/*.csv', recursive=True)



#random = random.sample(datapath, 100)

y_hat = []
y_target = []
for file in datapath:
    y_pred, y = validation(file)
    y_hat.append(y_pred)
    y_target.append(y)
    
target_names = ['0', '1', '2', '3', '4']
print('########## 전류데이터 유효검증 결과 ##########')
print(f"검증데이터수: {len(y_hat)} 개")

accuracy = accuracy_score(y_target, y_hat)
print('예측 정확도: {0:.4f}'.format(accuracy))
#print(classification_report(y_target, y_hat, target_names=target_names, digits=4)) 
print('종료시간(UCT+09:00)',datetime.datetime.now(pytz.timezone('Asia/Seoul')).strftime("%Y-%m-%d %H:%M:%S"))

end = time.time()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# Filename:STFCB-20201012-0105-0159_20201104_175008_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201104_174907_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201105_131805_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_122206_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_124905_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_122805_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_125105_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_122406_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_122205_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_124907_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_124906_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_122807_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_122405_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_111806_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_122207_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201105_131807_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_122407_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_125906_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_131707_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_125705_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_125706_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_125707_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_125206_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_125907_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_134906_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_125306_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_134905_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_134907_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_131705_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_125905_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_125505_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_184505_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_184606_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_181707_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_184608_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_204905_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_214905_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_184905_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_184507_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_181705_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_184906_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_195008_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_204907_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_191905_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_211907_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_194907_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_211905_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_101807_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_122305_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_122106_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_214906_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_214907_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_224706_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_101805_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_224907_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_224906_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_114907_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_224905_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_122505_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_221906_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_114905_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_122307_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_234905_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_221705_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_221905_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201106_221907_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_121906_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_122707_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_122706_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_125107_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_122906_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_125105_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_122506_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_122705_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_122905_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_122507_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20201107_122907_002.csv, Prediction:0, Y_Target:0
# Filename:STFCB-20201012-0105-0159_20210113_091306_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091406_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091305_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091307_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091207_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091208_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091206_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091405_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091205_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091407_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091807_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091706_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091705_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091506_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091806_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091905_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091507_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091606_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091505_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091805_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091605_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091607_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091707_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094206_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094307_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094605_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094306_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094106_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094107_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094305_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094505_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091906_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094506_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_091907_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094105_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094508_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094407_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094207_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094507_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094208_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101007_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_095007_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094806_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094606_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101205_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094905_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101006_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094805_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094906_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094807_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_095006_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101106_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101005_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_095008_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094607_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094907_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101107_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101108_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101305_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101307_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101206_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101105_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101406_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094405_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101405_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101505_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101506_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101207_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_094406_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101306_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101407_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101507_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104105_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101707_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101605_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101706_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104106_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101607_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104107_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101606_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_101705_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104405_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104206_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104207_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104306_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104406_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104307_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104305_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104407_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104205_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104505_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104506_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104806_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_105006_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104807_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104705_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_105007_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104607_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104508_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104606_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_105108_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104707_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104805_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_105005_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104507_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104605_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_105106_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_104706_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111307_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111405_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111106_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111005_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111007_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111206_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111305_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111105_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_105107_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111306_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111205_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111107_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111108_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111006_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111207_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111507_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114107_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111606_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111506_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114207_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114305_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111806_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111807_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114106_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111805_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114307_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114208_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111607_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111605_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111407_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114105_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111406_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_111505_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114505_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114707_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114805_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114806_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114406_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114405_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114507_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114607_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114708_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114605_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114706_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114306_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114506_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114807_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114206_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114407_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114606_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_115007_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121305_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121006_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121007_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121106_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_115008_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121307_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114907_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121107_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114905_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121306_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121406_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121207_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121206_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121205_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_114906_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121005_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121105_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_115006_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121605_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121507_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121805_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121408_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121607_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121505_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121506_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121606_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_122206_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121705_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_122405_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_122306_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121608_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121407_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_124106_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_124306_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121707_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_124105_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_121807_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_124107_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_122406_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_124305_002.csv, Prediction:1, Y_Target:1
# Filename:STFCB-20201012-0105-0159_20210113_122305_002.csv, Prediction:1, Y_Target:1
# ########## 전류데이터 유효검증 결과 ##########
# 검증데이터수: 277 개
# 예측 정확도: 1.0000
# 종료시간(UCT+09:00) 2021-08-09 20:06:20

# %%
elapsed_time = end-start
print(f"검증소요시간：{elapsed_time}초")

y_prediction = pd.DataFrame(y_hat)
y_prediction.to_csv('y_predict_current.csv', index=False)
# Out:
# 검증소요시간：7.800654888153076초
