# %%
# !pip install -U finance-datareader
# Out:
# ...
#      ---------------------------------------- 46.6/46.6 kB 1.2 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.1.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install plotly
# Out:
# ...
#      --------------------------------------- 15.7/15.7 MB 10.5 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.1.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import FinanceDataReader as fdr

# %%
df = fdr.StockListing('KRX')

# %%
df
# Out:
#         Code        ISU_CD      Name Market   Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자  KOSPI          77600          2
# 1     000660  KR7000660001    SK하이닉스  KOSPI         173300          2
# 2     373220  KR7373220003  LG에너지솔루션  KOSPI         367000          2
# 3     207940  KR7207940008  삼성바이오로직스  KOSPI         781000          2
# 4     005935  KR7005931001     삼성전자우  KOSPI          65200          2
# ...      ...           ...       ...    ...    ...     ...        ...
# 2798  217320  KR7217320001       썬테크  KONEX  일반기업부    2500          0
# 2799  413300  KR7413300005   티엘엔지니어링  KONEX  일반기업부    1995          2
# 2800  245450  KR7245450002    씨앤에스링크  KONEX  일반기업부    1640          2
# 2801  308700  KR7308700004       테크엔  KONEX  일반기업부     199          0
# 2802  322190  KR7322190000        베른  KONEX  일반기업부      16          3
#
#       Changes  ChagesRatio    Open    High     Low    Volume         Amount  \
# ...

# %%
filtered_df = df[df['Name'] == 'LG이노텍']

# %%
filtered_df
# Out:
#       Code        ISU_CD   Name Market Dept   Close ChangeCode  Changes  \
# 82  011070  KR7011070000  LG이노텍  KOSPI       181300          2    -5300
#
#     ChagesRatio    Open    High     Low  Volume       Amount         Marcap  \
# 82        -2.84  184700  186400  179500  134717  24565629800  4290846499100
#
#       Stocks MarketId
# 82  23667107      STK
